# %%
# !python --version
# Out:
# Python 3.8.6

# %%
# !pip install paddlepaddle==2.5.1 -i https://pypi.tuna.tsinghua.edu.cn/simple
# !pip install opencv-python
# !pip install paddleocr
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#      --------------------------------------- 0.0/72.0 MB 259.2 kB/s eta 0:04:38
#      --------------------------------------- 0.0/72.0 MB 245.8 kB/s eta 0:04:53
#      --------------------------------------- 0.1/72.0 MB 326.8 kB/s eta 0:03:40
#      --------------------------------------- 0.1/72.0 MB 467.6 kB/s eta 0:02:34
#      --------------------------------------- 0.2/72.0 MB 581.0 kB/s eta 0:02:04
#      --------------------------------------- 0.3/72.0 MB 747.0 kB/s eta 0:01:36
#      --------------------------------------- 0.4/72.0 MB 955.7 kB/s eta 0:01:15
#      ---------------------------------------- 0.5/72.0 MB 1.2 MB/s eta 0:00:59
#      ---------------------------------------- 0.6/72.0 MB 1.3 MB/s eta 0:00:54
# ...

# %%
import numpy as np
from paddleocr import PaddleOCR, draw_ocr
import cv2
import pandas as pd
import re

# %%
img = cv2.imread(r'C:\Merry\Homework\230801_OCR\bill.jpg', cv2.IMREAD_GRAYSCALE)
# _, img_bin = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
# 이진화하면 한자로도 읽힘..
# cv2.imshow('img_bin',img_bin)
# cv2.waitKey()

# %%
# 000을 검출하지 못해서 가로 사이즈를 줄여 45000 통째로 검출하게 함
cv2.resize(img,dsize=None, fx=0.7, fy=1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 000을 검출하지 못해서 가로 사이즈를 줄여 45000 통째로 검출하게 함
# ----> 2 cv2.resize(img,dsize=None, fx=0.7, fy=1)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
det_model_dir_path = r'C:\Merry\Homework\230801_OCR\db_resnet50_model'
ocr_korean = PaddleOCR(use_angle_cls=True, lang='korean')
img_path = r'C:\Merry\Homework\230801_OCR\bill.jpg'

result_ko = ocr_korean.ocr(img, cls=True)
en_li = []
for line in result_ko:
    for i in line:
        en_li.append(i[-1][0])
    print(len(line))
en_li = ''.join(en_li)
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/multilingual/Multilingual_PP-OCRv3_det_infer.tar to C:\Users\Administrator/.paddleocr/whl\det\ml\Multilingual_PP-OCRv3_det_infer\Multilingual_PP-OCRv3_det_infer.tar
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 3.85M/3.85M [00:05<00:00, 685kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/multilingual/korean_PP-OCRv4_rec_infer.tar to C:\Users\Administrator/.paddleocr/whl\rec\korean\korean_PP-OCRv4_rec_infer\korean_PP-OCRv4_rec_infer.tar
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 24.4M/24.4M [00:13<00:00, 1.87MiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to C:\Users\Administrator/.paddleocr/whl\cls\ch_ppocr_mobile_v2.0_cls_infer\ch_ppocr_mobile_v2.0_cls_infer.tar
# ...

# %%
en_li

# %%
name_pattern = '매장명]:\s'
date_pattern = r'\d{2}\/\d{2}\/\d{2}'
total_pattern = '합계:\s*(\d+)'

# %%
date = re.findall(date_pattern, en_li)
total = re.findall(total_pattern, en_li)

# %%
print(date)
print(total)

# %%
df = pd.DataFrame(columns='result_en', data=result_en)
print(df)
